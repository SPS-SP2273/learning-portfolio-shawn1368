# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Loops (Good)</span></div>

# %% [markdown]
# ## 1 Interrupting the flow

# %% [markdown]
# ## 2 List comprehension!

# %% [markdown]
# ### 2.1 Basic syntax

# %%
# Your code here

# %% [markdown]
# ### 2.2 List comprehension with conditions

# %%
# Your code here

# %% [markdown]
# ## 3 Other useful stuff

# %% [markdown]
# ### 3.1 for with unpacking

# %%
# Your code here

# %% [markdown]
# ### 3.2 for with a zip()

# %%
# Your code here

# %% [markdown]
# ### 3.3 for with dictionaries

# %%
# Your code here

# %% [markdown]
# ## Exercise 1 :  Make me an odd list

# %%
# %%timeit
# Your solution here
odd_sq = []
for x in range(10):
    if x % 2 == 1:
        odd_sq.append(x**2)
# Out:
# 1.91 µs ± 387 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Exercise 2 :  Make me another odd list

# %%
# %%timeit


# Your solution here

odd_sq_comp = [x ** 2 for x in range(10) if x % 2 == 1]
# Out:
# 1.53 µs ± 139 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Exercise 3 :  Time me!

# %% [markdown]
# The list comprehension was faster than the for loop.
